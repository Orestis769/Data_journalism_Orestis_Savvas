# %% [markdown]
# <a href="https://colab.research.google.com/github/Orestis769/Data_journalism_Orestis_Savvas/blob/main/%CE%86%CF%83%CE%BA%CE%B7%CF%83%CE%B7_1_Orestis_Savvas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <span style="color:red">*Άσκηση 1*</span>
#
# <span style="color:red">
#
# Αλλάξτε το όνομα του notebook βάζοντας το όνομά σας και homework-1-part1-lastname
#
# Ακριβώς κάτω από αυτό το κελί προσθέστε νέα κελιά στα οποία θα:
#
# Θα φτιάξετε μια λίστα με τους παρακάτω αριθμούς: 23, 91, 0, -11, 4, 23 και 49.
# Βρείτε τον αριθμό των αντικειμένων της λίστας.
# Βρείτε το 4ο στοιχείο της λίστας.
# Βρείτε το άθροισμα του 2ου και του 4ου στοιχείου της λίστας.
# Βρείτε το 2ο μεγαλύτερο στοιχείο της λίστας.
# Βρείτε το τελευταίο αντικείμενο της αρχικής λίστας (χωρίς σορτάρισμα).
# Για κάθε αριθμό να εμφανίσετε έναν αριθμό: αν ο αρχικός αριθμός είναι μεγαλύτερος του 10, πολλαπλασιάστε με το 30. Αν επίσης είναι ζυγός αριθμός, προσθέστε 6. Αν είναι μεγαλύτερος του 50, αφαιρέστε 10. Αν δεν είναι ίσος με -11, αφαιρέστε 1. (Για παράδειγμα το 12 είναι μεγαλύτερο του 10, άρα πολλαπλασιάζουμε 12 * 30 = 360, είναι επίσης ζυγός αριθμός, άρα 360 + 6 = 366, δεν είναι ίσο με -11, άρα 366-1=365.)
#
# Βρείτε το σύνολο των αριθμών δια δύο.
# </span>

# %%
list = [23, 91, 0, -11, 4, 23, 49]
list2 = sorted(list)
print(f"arithmos antikimenon {len(list)}\ntetarto stixio listas {list[3]}\nathrisma 2 kai tetartou {list[1] + list[3]}\nTo deftero megalitero tis lista {list2[-2]} {list2}\n")

#task 2
for i in range(0, len(list)):
  if list[i] > 10:
    print(f"πολλαπλασιάστε με το 30 ton aritho {list[i]} {list[i] * 30}")
  if list[i] % 2 == 0:
    print(f"Αν επίσης είναι ζυγός αριθμός, προσθέστε 6 {list[i]} {list[i] + 6}")
  if list[i] > 50:
    print(f"Αν είναι μεγαλύτερος του 50, αφαιρέστε 10 {list[i]} {list[i] - 10}")
  if list[i] != -11:
    print(f"Αν δεν είναι ίσος με -11, αφαιρέστε 1 {list[i]} {list[i] - 1}")
# Out:
# arithmos antikimenon 7
# tetarto stixio listas -11
# athrisma 2 kai tetartou 80
# To deftero megalitero tis lista 49 [-11, 0, 4, 23, 23, 49, 91]
#
# πολλαπλασιάστε με το 30 ton aritho 23 690
# Αν δεν είναι ίσος με -11, αφαιρέστε 1 23 22
# πολλαπλασιάστε με το 30 ton aritho 91 2730
# Αν είναι μεγαλύτερος του 50, αφαιρέστε 10 91 81
# Αν δεν είναι ίσος με -11, αφαιρέστε 1 91 90
# Αν επίσης είναι ζυγός αριθμός, προσθέστε 6 0 6
# Αν δεν είναι ίσος με -11, αφαιρέστε 1 0 -1
# Αν επίσης είναι ζυγός αριθμός, προσθέστε 6 4 10
# Αν δεν είναι ίσος με -11, αφαιρέστε 1 4 3
# πολλαπλασιάστε με το 30 ton aritho 23 690
# Αν δεν είναι ίσος με -11, αφαιρέστε 1 23 22
# πολλαπλασιάστε με το 30 ton aritho 49 1470
# Αν δεν είναι ίσος με -11, αφαιρέστε 1 49 48
